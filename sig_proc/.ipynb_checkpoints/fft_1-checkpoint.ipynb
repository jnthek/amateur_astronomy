# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,1,1000)
sig = np.sin(2*np.pi*t*10 + np.pi/4)
sig_fft = np.fft.fft(sig)[0:500]

# %%
plt.plot(np.angle(sig_fft))

# %%
plt.plot(np.abs(sig_fft))
